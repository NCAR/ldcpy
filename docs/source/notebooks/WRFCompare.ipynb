# %% [markdown]
# # WRF basic notebook
#
# This notebook does some basic WRF comparisons *without* using LDCPY.
#
# On NCAR's Jupyterhub, environment NPL 2024b is a good option.
#
# if this environment variable is not set, then you can set it as needed:

# %%
# if this environment variable is not set, then you can set it as needed:
os.environ['HDF5_PLUGIN_PATH'] = '/glade/work/abaker/compress-libs/plugins_mar26/lib64'

# %%
# conda env:npl_2024b
import os

import cartopy
import cmocean
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import xwrf
from cartopy import crs as ccrs

# %matplotlib inline

# %% [markdown]
# To look at SPERR-compressed data, you need the HDF5 plugin installed and the path specified in HDF5_PLUGIN_PATH. So let's verify that.  (Note, I have all my plugins in the same zfp directory)

# %%
os.environ["HDF5_PLUGIN_PATH"]
# Out:
# '/glade/work/abaker/compress-libs/plugins_mar26/lib64'

# %%
# Some CONUS 404 wrf data to look at (24 hourly sliced put into a single file)
# (wrf2d_d01_2020-07-01_00:00:00 => wrf2d_d01_2020-07-01_23:00:00 , and then for 3d also)
mydir = "/glade/campaign/cisl/asap/abaker/wrf_update/wrf_24hr_combined_files/allvars/wrf_compress/"
file2d = "wrf2d_combined.nc"
file3d = "wrf3d_combined.nc"
# original data
o_file2d = mydir + "lossless/" + file2d
o_file3d = mydir + "lossless/" + file3d
# look at a granular bit rounded file w/3 sig figs
gbr_file2d = mydir + "gbr_3/" + file2d
gbr_file3d = mydir + "gbr_3/" + file3d
# look at a sperr file with psnr=100
sp_file2d = mydir + "sperr_psnr100/" + file2d
sp_file3d = mydir + "sperr_psnr100/" + file3d

# this contains lat/lon info
fileconsts = "/glade/campaign/cisl/asap/abaker/wrf_update/wrfconstants_usgs404.nc"

# %%
# open and process wrf files to work with properly with xarray
ds_o_2d = xr.open_dataset(o_file2d, engine="netcdf4").xwrf.postprocess()
ds_o_3d = xr.open_dataset(o_file3d, engine="netcdf4").xwrf.postprocess()

ds_gbr_2d = xr.open_dataset(gbr_file2d, engine="netcdf4").xwrf.postprocess()
ds_gbr_3d = xr.open_dataset(gbr_file3d, engine="netcdf4").xwrf.postprocess()

ds_sp_2d = xr.open_dataset(sp_file2d, engine="netcdf4").xwrf.postprocess()
ds_sp_3d = xr.open_dataset(sp_file3d, engine="netcdf4").xwrf.postprocess()

# %%
# lat and lon info is in the const file (unless you are using the wrf conus404 rda data, when you don't need this)
ds_const = xr.open_dataset(fileconsts, engine="netcdf4").xwrf.postprocess()

# %%
# what's in the file
ds_const.coords
# Out:
# Coordinates:
#     XLAT     (y, x) float32 6MB ...
#     XLONG    (y, x) float32 6MB ...
#     XLAT_U   (y, x_stag) float32 6MB ...
#     XLONG_U  (y, x_stag) float32 6MB ...
#     XLAT_V   (y_stag, x) float32 6MB ...
#     XLONG_V  (y_stag, x) float32 6MB ...
#     XTIME    (Time) datetime64[ns] 8B 1979-10-01
#   * z        (z) float32 200B 0.9969 0.9901 0.9821 ... 0.0161 0.009015 0.0028
#   * z_stag   (z_stag) float32 204B 1.0 0.9938 0.9864 ... 0.01243 0.0056 0.0
#   * Time     (Time) datetime64[ns] 8B 1979-10-01
#   * y_stag   (y_stag) float64 8kB -2.03e+06 -2.026e+06 ... 2.026e+06 2.03e+06
#   * x_stag   (x_stag) float64 11kB -2.734e+06 -2.73e+06 ... 2.73e+06 2.734e+06
#   * x        (x) float64 11kB -2.732e+06 -2.728e+06 ... 2.728e+06 2.732e+06
#   * y        (y) float64 8kB -2.028e+06 -2.024e+06 ... 2.024e+06 2.028e+06

# %%
# get the lat and lon from the coords
wrf_lon = ds_const.coords["XLONG"]
wrf_lat = ds_const.coords["XLAT"]
# for V vars
wrf_lon_v = ds_const.coords["XLONG_U"]
wrf_lat_v = ds_const.coords["XLAT_U"]
# for U vars
wrf_lon_u = ds_const.coords["XLONG_U"]
wrf_lat_u = ds_const.coords["XLAT_U"]

# %%
# To see all the vars and descriptions
for var in ds_o_2d:
    try:
        print(f'variable: {var}, description: {ds_o_2d[var].description}')
    except:
        pass
# Out:
# variable: Q2, description: QV at 2 M
# variable: T2, description: TEMP at 2 M
# variable: TH2, description: POT TEMP at 2 M
# variable: PSFC, description: SFC PRESSURE
# variable: U10, description: U at 10 M
# variable: V10, description: V at 10 M
# variable: TSLB, description: SOIL TEMPERATURE
# variable: SMOIS, description: SOIL MOISTURE
# variable: SH2O, description: SOIL LIQUID WATER
# variable: SEAICE, description: SEA ICE FLAG
# variable: ACSNOM, description: ACCUMULATED MELTED SNOW
# variable: SNOW, description: SNOW WATER EQUIVALENT
# variable: SNOWH, description: PHYSICAL SNOW DEPTH
# variable: CANWAT, description: CANOPY WATER
# variable: SSTSK, description: SKIN SEA SURFACE TEMPERATURE
# variable: COSZEN, description: COS of SOLAR ZENITH ANGLE
# variable: LAI, description: LEAF AREA INDEX
# variable: TSK, description: SURFACE SKIN TEMPERATURE
# variable: RAINNCV, description: TIME-STEP NONCONVECTIVE PRECIPITATION
# variable: SWDOWN, description: DOWNWARD SHORT WAVE FLUX AT GROUND SURFACE
# variable: GLW, description: DOWNWARD LONG WAVE FLUX AT GROUND SURFACE
# variable: SWNORM, description: NORMAL SHORT WAVE FLUX AT GROUND SURFACE (SLOPE-DEPENDENT)
# variable: ACSWUPT, description: ACCUMULATED UPWELLING SHORTWAVE FLUX AT TOP
# variable: ACSWUPTC, description: ACCUMULATED UPWELLING CLEAR SKY SHORTWAVE FLUX AT TOP
# variable: ACSWDNT, description: ACCUMULATED DOWNWELLING SHORTWAVE FLUX AT TOP
# variable: ACSWDNTC, description: ACCUMULATED DOWNWELLING CLEAR SKY SHORTWAVE FLUX AT TOP
# variable: ACSWUPB, description: ACCUMULATED UPWELLING SHORTWAVE FLUX AT BOTTOM
# variable: ACSWUPBC, description: ACCUMULATED UPWELLING CLEAR SKY SHORTWAVE FLUX AT BOTTOM
# variable: ACSWDNB, description: ACCUMULATED DOWNWELLING SHORTWAVE FLUX AT BOTTOM
# variable: ACSWDNBC, description: ACCUMULATED DOWNWELLING CLEAR SKY SHORTWAVE FLUX AT BOTTOM
# variable: ACLWUPT, description: ACCUMULATED UPWELLING LONGWAVE FLUX AT TOP
# variable: ACLWUPTC, description: ACCUMULATED UPWELLING CLEAR SKY LONGWAVE FLUX AT TOP
# variable: ACLWDNT, description: ACCUMULATED DOWNWELLING LONGWAVE FLUX AT TOP
# variable: ACLWDNTC, description: ACCUMULATED DOWNWELLING CLEAR SKY LONGWAVE FLUX AT TOP
# variable: ACLWUPB, description: ACCUMULATED UPWELLING LONGWAVE FLUX AT BOTTOM
# variable: ACLWUPBC, description: ACCUMULATED UPWELLING CLEAR SKY LONGWAVE FLUX AT BOTTOM
# variable: ACLWDNB, description: ACCUMULATED DOWNWELLING LONGWAVE FLUX AT BOTTOM
# variable: ACLWDNBC, description: ACCUMULATED DOWNWELLING CLEAR SKY LONGWAVE FLUX AT BOTTOM
# variable: I_ACSWUPT, description: BUCKET FOR UPWELLING SHORTWAVE FLUX AT TOP
# variable: I_ACSWUPTC, description: BUCKET FOR UPWELLING CLEAR SKY SHORTWAVE FLUX AT TOP
# variable: I_ACSWDNT, description: BUCKET FOR DOWNWELLING SHORTWAVE FLUX AT TOP
# variable: I_ACSWDNTC, description: BUCKET FOR DOWNWELLING CLEAR SKY SHORTWAVE FLUX AT TOP
# variable: I_ACSWUPB, description: BUCKET FOR UPWELLING SHORTWAVE FLUX AT BOTTOM
# variable: I_ACSWUPBC, description: BUCKET FOR UPWELLING CLEAR SKY SHORTWAVE FLUX AT BOTTOM
# variable: I_ACSWDNB, description: BUCKET FOR DOWNWELLING SHORTWAVE FLUX AT BOTTOM
# variable: I_ACSWDNBC, description: BUCKET FOR DOWNWELLING CLEAR SKY SHORTWAVE FLUX AT BOTTOM
# variable: I_ACLWUPT, description: BUCKET FOR UPWELLING LONGWAVE FLUX AT TOP
# variable: I_ACLWUPTC, description: BUCKET FOR UPWELLING CLEAR SKY LONGWAVE FLUX AT TOP
# variable: I_ACLWDNT, description: BUCKET FOR DOWNWELLING LONGWAVE FLUX AT TOP
# variable: I_ACLWDNTC, description: BUCKET FOR DOWNWELLING CLEAR SKY LONGWAVE FLUX AT TOP
# variable: I_ACLWUPB, description: BUCKET FOR UPWELLING LONGWAVE FLUX AT BOTTOM
# variable: I_ACLWUPBC, description: BUCKET FOR UPWELLING CLEAR SKY LONGWAVE FLUX AT BOTTOM
# variable: I_ACLWDNB, description: BUCKET FOR DOWNWELLING LONGWAVE FLUX AT BOTTOM
# variable: I_ACLWDNBC, description: BUCKET FOR DOWNWELLING CLEAR SKY LONGWAVE FLUX AT BOTTOM
# variable: SWUPT, description: INSTANTANEOUS UPWELLING SHORTWAVE FLUX AT TOP
# variable: SWUPTC, description: INSTANTANEOUS UPWELLING CLEAR SKY SHORTWAVE FLUX AT TOP
# variable: SWDNT, description: INSTANTANEOUS DOWNWELLING SHORTWAVE FLUX AT TOP
# variable: SWDNTC, description: INSTANTANEOUS DOWNWELLING CLEAR SKY SHORTWAVE FLUX AT TOP
# variable: SWUPB, description: INSTANTANEOUS UPWELLING SHORTWAVE FLUX AT BOTTOM
# variable: SWUPBC, description: INSTANTANEOUS UPWELLING CLEAR SKY SHORTWAVE FLUX AT BOTTOM
# variable: SWDNB, description: INSTANTANEOUS DOWNWELLING SHORTWAVE FLUX AT BOTTOM
# variable: SWDNBC, description: INSTANTANEOUS DOWNWELLING CLEAR SKY SHORTWAVE FLUX AT BOTTOM
# variable: LWUPT, description: INSTANTANEOUS UPWELLING LONGWAVE FLUX AT TOP
# variable: LWUPTC, description: INSTANTANEOUS UPWELLING CLEAR SKY LONGWAVE FLUX AT TOP
# variable: LWDNT, description: INSTANTANEOUS DOWNWELLING LONGWAVE FLUX AT TOP
# variable: LWDNTC, description: INSTANTANEOUS DOWNWELLING CLEAR SKY LONGWAVE FLUX AT TOP
# variable: LWUPB, description: INSTANTANEOUS UPWELLING LONGWAVE FLUX AT BOTTOM
# variable: LWUPBC, description: INSTANTANEOUS UPWELLING CLEAR SKY LONGWAVE FLUX AT BOTTOM
# variable: LWDNB, description: INSTANTANEOUS DOWNWELLING LONGWAVE FLUX AT BOTTOM
# variable: LWDNBC, description: INSTANTANEOUS DOWNWELLING CLEAR SKY LONGWAVE FLUX AT BOTTOM
# variable: OLR, description: TOA OUTGOING LONG WAVE
# variable: ALBEDO, description: ALBEDO
# variable: EMISS, description: SURFACE EMISSIVITY
# variable: TV, description: vegetation leaf temperature
# variable: TG, description: bulk ground temperature
# variable: TSNO, description: snow temperature
# variable: ZSNSO, description: layer-bottom depth from snow surf
# variable: SNICE, description: snow layer ice
# variable: SNLIQ, description: snow layer liquid
# variable: TRAD, description: surface radiative temperature
# variable: QSLAT, description: sum lateral flow
# variable: QRFS, description: sum baseflow
# variable: RECH, description: sum water table recharge
# variable: QSPRINGS, description: sum seeping water
# variable: ACINTS, description: acccumlated QINTS
# variable: ACINTR, description: acccumlated QINTR
# variable: ACDRIPR, description: acccumlated QDRIPR
# variable: ACTHROR, description: acccumlated QTHROR
# variable: ACEVAC, description: acccumlated QEVAC
# variable: ACDEWC, description: acccumlated QDEWC
# variable: FORCTLSM, description: lowest model T into LSM
# variable: FORCQLSM, description: lowest model Q into LSM
# variable: FORCPLSM, description: lowest model P into LSM
# variable: FORCZLSM, description: lowest model Z into LSM
# variable: FORCWLSM, description: lowest model wind speed into LSM
# variable: CANICE, description: intercepted ice mass
# variable: SMCWTD, description: deep soil moisture
# variable: ZWT, description: water table depth
# variable: ACRAINLSM, description: acccumlated RAINLSM
# variable: ACRUNSB, description: acccumlated RUNSF
# variable: ACRUNSF, description: acccumlated RUNSB
# variable: ACECAN, description: acccumlated ECAN
# variable: ACETRAN, description: acccumlated ETRAN
# variable: ACEDIR, description: acccumlated EDIR
# variable: ACQLAT, description: accumulated lateral flow
# variable: ACQRF, description: accumulated baseflow
# variable: ACETLSM, description: acccumlated ET
# variable: ACSNOWLSM, description: acccumlated SNOWLSM
# variable: ACSUBC, description: acccumlated QSUBC
# variable: ACFROC, description: acccumlated QFROC
# variable: ACFRZC, description: acccumlated QFRZC
# variable: ACMELTC, description: acccumlated QMELTC
# variable: ACSNBOT, description: acccumlated QSNBOT
# variable: ACPONDING, description: acccumlated PONDING
# variable: ACSNSUB, description: acccumlated QSNSUB
# variable: ACSNFRO, description: acccumlated QSNFRO
# variable: ACRAINSNOW, description: acccumlated rain on snow pack
# variable: ACDRIPS, description: acccumlated QDRIPS
# variable: ACTHROS, description: acccumlated QTHROS
# variable: ACSAGB, description: acccumlated SAG under vegetation
# variable: ACIRB, description: acccumlated IRB
# variable: ACSHB, description: acccumlated SHB
# variable: ACEVB, description: acccumlated EVB
# variable: ACGHB, description: acccumlated GHB
# variable: ACPAHB, description: acccumlated PAHB
# variable: ACSAGV, description: acccumlated SAG in bare section
# variable: ACIRG, description: acccumlated IRG
# variable: ACSHG, description: acccumlated SHG
# variable: ACEVG, description: acccumlated EVG
# variable: ACGHV, description: acccumlated GHV
# variable: ACPAHG, description: acccumlated PAHG
# variable: ACSAV, description: acccumlated SAV
# variable: ACIRC, description: acccumlated IRC
# variable: ACSHC, description: acccumlated SHC
# variable: ACEVC, description: acccumlated EVC
# variable: ACTR, description: acccumlated TR
# variable: ACPAHV, description: acccumlated PAHV
# variable: ACSWDNLSM, description: acccumlated SWDN
# variable: ACSWUPLSM, description: acccumlated SWUP
# variable: ACLWDNLSM, description: acccumlated LWDN
# variable: ACLWUPLSM, description: acccumlated LWUP
# variable: ACSHFLSM, description: acccumlated total sensible heat flux
# variable: ACLHFLSM, description: acccumlated total latent heat flux
# variable: ACGHFLSM, description: acccumlated total ground heat flux
# variable: ACPAHLSM, description: acccumlated total precip heat flux
# variable: SOILENERGY, description: energy content in soil relative to 273.16
# variable: SNOWENERGY, description: energy content in snow relative to 273.16
# variable: UST, description: U* IN SIMILARITY THEORY
# variable: PBLH, description: PBL HEIGHT
# variable: HFX, description: UPWARD HEAT FLUX AT THE SURFACE
# variable: QFX, description: UPWARD MOISTURE FLUX AT THE SURFACE
# variable: LH, description: LATENT HEAT FLUX AT THE SURFACE
# variable: SNOWC, description: FLAG INDICATING SNOW COVERAGE (1 FOR SNOW COVER)
# variable: SR, description: fraction of frozen precipitation
# variable: REFL_1KM_AGL, description: 1KM AGL REFLECTIVITY
# variable: REFL_COM, description: COMPOSITE REFLECTIVITY
# variable: SBCAPE, description: SURFACE-BASED CAPE
# variable: MLCAPE, description: MIXED-LAYER CAPE
# variable: MUCAPE, description: MOST-UNSTABLE CAPE
# variable: SBCINH, description: SURFACE-BASED CINH
# variable: MLCINH, description: MIXED-LAYER CINH
# variable: MUCINH, description: MOST-UNSTABLE CINH
# variable: SBLCL, description: SURFACE-BASED LCL
# variable: MLLCL, description: MIXED-LAYER LCL
# variable: USHR1, description: 0-1km AGL U-component Wind Shear
# variable: USHR6, description: 0-6km AGL U-component Wind Shear
# variable: VSHR1, description: 0-1km AGL V-component Wind Shear
# variable: VSHR6, description: 0-6km AGL V-component Wind Shear
# variable: U_BUNK, description: U-component of Bunkers storm motion
# variable: V_BUNK, description: V-component of Bunkers storm motion
# variable: SRH01, description: 0-1km storm-relative helicity
# variable: SRH03, description: 0-3km storm-relative helicity
# variable: TD2, description: 2-m dewpoint temperature
# variable: PREC_ACC_NC, description: ACCUMULATED GRID SCALE  PRECIPITATION OVER prec_acc_dt PERIODS OF TIME
# variable: SNOW_ACC_NC, description: ACCUMULATED SNOW WATER EQUIVALENT OVER prec_acc_dt PERIODS OF TIME
# variable: GRAUPEL_ACC_NC, description: ACCUMULATED GRAUPEL WATER EQUIVALENT OVER prec_acc_dt PERIODS OF TIME
# variable: SST, description: SEA SURFACE TEMPERATURE
# variable: MU, description: dry airmass in column (MU+MUB)
# variable: TK, description: Air temperature at the lowest model level
# variable: P, description: Total pressure at the lowest model level (P + PB)
# variable: Z, description: Geopotential Height at the lowest model level (PH+PHB)/9.81
# variable: PWAT, description: Precipitable Water
# variable: totalLiq, description: Cloud water mixing ratio
# variable: totalIce, description: Ice mixing ratio
# variable: totalVap, description: Water vapor mixing ratio
# variable: REFL_10CM, description: REFL_10CM at the lowest model level
# variable: QVAPOR, description: QVAPOR at the lowest model level
# variable: U, description: U at the lowest model level
# variable: V, description: V at the lowest model level
# variable: W, description: W at the lowest model level

# %%
# grab var of interest at time=0 for 2D
var = "Q2"
o_var = ds_o_2d[var].isel(Time=0)
gbr_var = ds_gbr_2d[var].isel(Time=0)
sp_var = ds_sp_2d[var].isel(Time=0)

# %%
# basic xarray quick plot of original data
# (note: lat and lon not in the file)

o_var.plot()

# %%
# compressed with GBR
gbr_var.plot()

# %%
# compressed with sperr
sp_var.plot()

# %%
# a bit fancier: incorporate correct projection as well as lat/lon info
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

mymap = cmocean.cm.thermal
tt = ax.pcolormesh(wrf_lon, wrf_lat, o_var.data, cmap=mymap)
ax.set_title(var + " (time slice = 0)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Temp. (K)")
plt.show()

# %%
# incorporate correct projection as well as lat/lon info - GBR
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = cmocean.cm.thermal
tt = ax.pcolormesh(wrf_lon, wrf_lat, gbr_var.data, cmap=mymap)
ax.set_title(var + " (time slice = 0) with GBR=3")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Temp. (K)")
plt.show()

# %%
# incorporate correct projection as well as lat/lon info - SPERR p100
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = cmocean.cm.thermal
tt = ax.pcolormesh(wrf_lon, wrf_lat, sp_var.data, cmap=mymap)
ax.set_title(var + " (time slice = 0) with PSNR=100")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Temp. (K)")
plt.show()

# %%
# plot the difference -GBR
diff_var = o_var.data - gbr_var.data
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "coolwarm"
tt = ax.pcolormesh(wrf_lon, wrf_lat, diff_var, cmap=mymap)
ax.set_title(var + ": Difference (Orig - GBR=3)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Temp. (K)")
plt.show()

# %%
# plot the difference - sperr
sperr_diff_var = o_var.data - sp_var.data
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "coolwarm"
tt = ax.pcolormesh(wrf_lon, wrf_lat, sperr_diff_var, cmap=mymap)
ax.set_title(var + ": Difference (Orig - SPERR:PSNR=100")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Temp. (K)")
plt.show()

# %%
# if look at U or V, need different lat/lon values
# let's look at U
o_u = ds_o_2d["U"].isel(Time=0)
gbr_u = ds_gbr_2d["U"].isel(Time=0)
sp_u = ds_sp_2d["U"].isel(Time=0)

fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "Greens"
tt = ax.pcolormesh(wrf_lon_u, wrf_lat_u, o_u.data, cmap=mymap)
ax.set_title("U (time slice = 0)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Speed (m/s)")
plt.show()

# %%
# plot the difference for u (w/SPERR)
sp_diff_u = o_u.data - sp_u.data
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "coolwarm"
tt = ax.pcolormesh(wrf_lon_u, wrf_lat_u, sp_diff_u, cmap=mymap)
ax.set_title("U: Difference (Orig - SPERR:PSNR=100)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Speed (m/s)")
plt.show()

# %%
# plot the difference for u (GBR)
diff_u = o_u.data - gbr_u.data
fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "coolwarm"
tt = ax.pcolormesh(wrf_lon_u, wrf_lat_u, diff_u, cmap=mymap)
ax.set_title("U: Difference (Orig - GBR=3)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="Speed (m/s)")
plt.show()

# %%
# now do a 3d field - can just look at a single level (there are 50 levels)
# here we did level 30
cld_slice = ds_o_3d["CLDFRA"].isel(Time=0).isel(z=30)

fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "GnBu"
tt = ax.pcolormesh(wrf_lon, wrf_lat, cld_slice.data, cmap=mymap)
ax.set_title("CLDFRA (time slice = 0)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="cloud cover fraction")
plt.show()

# %%
# 3D field: here we did level 30
# look at the difference from a compressed one

sp_cloud_slice = ds_sp_3d["CLDFRA"].isel(Time=0).isel(z=30)
sp_diff_3d = cld_slice - sp_cloud_slice

fig = plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
mymap = "GnBu"
tt = ax.pcolormesh(wrf_lon, wrf_lat, sp_diff_3d.data, cmap=mymap)
ax.set_title("CLDFRA (z=30, t-0): Difference (Orig - SPERR:PSNR=100)")
ax.coastlines()
fig.colorbar(tt, shrink=0.85, label="cloud cover fraction")
plt.show()
